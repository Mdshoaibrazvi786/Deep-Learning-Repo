# %%
import numpy as  np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
or_data = pd.DataFrame()
and_data = pd.DataFrame()
xor_data = pd.DataFrame()

# %%
or_data['input1']=[1,1,0,0]
or_data['input2']=[1,0,1,0]
or_data['ouput']=[1,1,1,0]

# %%
and_data['input1']=[1,1,0,0]
and_data['input2']=[1,0,1,0]
and_data['output']=[1,0,0,0]

# %%
xor_data['input1']=[1,1,0,0]
xor_data['input2']=[1,0,1,0]
xor_data['output']=[0,1,1,0]

# %%
and_data
# Out:
#    input1  input2  output
# 0       1       1       1
# 1       1       0       0
# 2       0       1       0
# 3       0       0       0

# %%
sns.scatterplot(x=xor_data['input1'], y=xor_data['input2'], hue=xor_data['output'],s=200)
plt.show()

# %%
or_data
# Out:
#    input1  input2  ouput
# 0       1       1      1
# 1       1       0      1
# 2       0       1      1
# 3       0       0      0

# %%
sns.scatterplot(x=or_data['input1'], y=or_data['input2'], hue=or_data['ouput'],s=200)
plt.show()

# %%
xor_data
# Out:
#    input1  input2  output
# 0       1       1       0
# 1       1       0       1
# 2       0       1       1
# 3       0       0       0

# %%
sns.scatterplot(x=xor_data['input1'], y=xor_data['input2'], hue=xor_data['output'],s=200)
plt.show()

# %%
from sklearn.linear_model import Perceptron

# %%
clf1=Perceptron()
clf2=Perceptron()
clf3=Perceptron()

# %%
clf1.fit(and_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf1.fit(or_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
clf1.fit(xor_data.iloc[:,0:2].values,and_data.iloc[:,-1].values)
# Out:
# Perceptron()

# %%
clf1.coef_
# Out:
# array([[2., 2.]])

# %%
clf1.intercept_
# Out:
# array([-2.])

# %%
x=np.linspace(-1,1,5)
y=-x+1

# %%
plt.plot(x,y)
sns.scatterplot(x=and_data['input1'], y=and_data['input2'], hue=and_data['output'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
x1=np.linspace(-1,1,5)
y1=-x+0.5

# %%
plt.plot(x1,y1)
sns.scatterplot(x=or_data['input1'], y=or_data['input2'], hue=or_data['ouput'],s=200)
# Out:
# <Axes: xlabel='input1', ylabel='input2'>

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# Cell In[56], line 2
#       1 from mlxtend.plotting import plot_decision_regions
# ----> 2 plot_decision_regions(xor_data.iloc[:,0:2].values,xor_data.iloc[:,-1].values, clf=clf3, legend=2)
#       3 plt.show()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\mlxtend\plotting\decision_regions.py:272, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     270             X_predict[:, feature_idx] = filler_feature_values[feature_idx]
#     271 if n_jobs == 1:
# --> 272     Z = clf.predict(X_predict.astype(X.dtype))
#     273     Z = Z.reshape(xx.shape)
#     274 else:
#
# ...
