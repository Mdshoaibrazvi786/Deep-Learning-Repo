# %% [markdown]
# # Artificial Neural Network (ANN)
#
# ## What is ANN?
#
# Artificial Neural Network (ANN) is a Machine Learning model inspired by the human brain. It learns patterns by adjusting weights and biases through multiple training iterations.
#
# ---
#
# # Human Brain vs ANN
#
# | Human Brain | ANN |
# |-------------|-----|
# | Neuron | Artificial Neuron |
# | Synapse | Weight |
# | Signal | Input |
# | Brain Decision | Output |
#
# ---
#
# # ANN Architecture
#
# ```
# Input Layer
#       │
#       ▼
# Hidden Layer
#       │
#       ▼
# Output Layer
# ```
#
# ---
#
# # Artificial Neuron
#
# Each neuron performs:
#
# \[
# Z = \sum (W \times X) + B
# \]
#
# where
#
# - X = Input
# - W = Weight
# - B = Bias
# - Z = Weighted Sum
#
# ---
#
# # Activation Function
#
# Output is
#
# \[
# A = f(Z)
# \]
#
# Common activation functions
#
# - ReLU
# - Sigmoid
# - Tanh
# - Softmax
#
# ---
#
# # Example
#
# Inputs
#
# ```
# X1 = 2
# X2 = 3
# ```
#
# Weights
#
# ```
# W1 = 0.5
# W2 = 0.4
# ```
#
# Bias
#
# ```
# B = 1
# ```
#
# Weighted Sum
#
# \[
# Z=(2×0.5)+(3×0.4)+1
# \]
#
# \[
# Z=1+1.2+1
# \]
#
# \[
# Z=3.2
# \]
#
# ---
#
# # ReLU Activation
#
# Formula
#
# \[
# ReLU(x)=max(0,x)
# \]
#
# Since
#
# ```
# Z=3.2
# ```
#
# Output
#
# ```
# 3.2
# ```
#
# ---
#
# # Sigmoid Activation
#
# Formula
#
# \[
# \sigma(x)=\frac{1}{1+e^{-x}}
# \]
#
# For
#
# ```
# Z=3.2
# ```
#
# Output
#
# ```
# 0.96
# ```
#
# ---
#
# # Forward Propagation
#
# ```
# Input
#
# ↓
#
# Multiply by Weights
#
# ↓
#
# Add Bias
#
# ↓
#
# Activation Function
#
# ↓
#
# Prediction
# ```
#
# ---
#
# # Loss Function
#
# Measures prediction error.
#
# Mean Squared Error
#
# \[
# Loss=(Actual-Predicted)^2
# \]
#
# Example
#
# ```
# Actual = 1
#
# Prediction = 0.8
# ```
#
# Loss
#
# \[
# (1-0.8)^2=0.04
# \]
#
# ---
#
# # Backpropagation
#
# Steps
#
# ```
# Calculate Loss
#
# ↓
#
# Find Error
#
# ↓
#
# Calculate Gradient
#
# ↓
#
# Update Weights
#
# ↓
#
# Repeat
# ```
#
# ---
#
# # Weight Update Formula
#
# \[
# NewWeight=OldWeight-\eta\times Gradient
# \]
#
# Example
#
# ```
# Old Weight = 0.50
#
# Gradient = 0.20
#
# Learning Rate = 0.10
# ```
#
# New Weight
#
# ```
# 0.50-(0.10×0.20)
#
# =
#
# 0.48
# ```
#
# ---
#
# # Training Loop
#
# ```
# Input Data
#
# ↓
#
# Forward Propagation
#
# ↓
#
# Prediction
#
# ↓
#
# Loss Calculation
#
# ↓
#
# Backpropagation
#
# ↓
#
# Weight Update
#
# ↓
#
# Repeat Until Loss is Minimum
# ```
#
# ---
#
# # Hyperparameters
#
# - Learning Rate
# - Epochs
# - Batch Size
# - Hidden Layers
# - Neurons
# - Activation Function
#
# ---
#
# # Advantages
#
# - Learns complex patterns
# - High accuracy
# - Works for classification & regression
# - Foundation of Deep Learning
#
# ---
#
# # Limitations
#
# - Requires large dataset
# - High computation
# - Can overfit
# - Hyperparameter tuning required
#
# ---
#
# # Applications
#
# - Face Recognition
# - Medical Diagnosis
# - Stock Prediction
# - Fraud Detection
# - Speech Recognition
# - Recommendation Systems
#
# ---
#
# # Interview Questions
#
# ### What is ANN?
#
# ANN is a network of interconnected artificial neurons that learns patterns by adjusting weights and biases.
#
# ### What is Weight?
#
# Weight represents the importance of an input feature.
#
# ### What is Bias?
#
# Bias shifts the activation function and helps improve learning.
#
# ### Why Activation Function?
#
# To introduce non-linearity so the network can learn complex relationships.
#
# ### Why Backpropagation?
#
# To minimize loss by updating weights using gradients.
#
# ---
#
# # Complete ANN Flow
#
# ```
# Input
#    ↓
# Weights
#    ↓
# Weighted Sum
#    ↓
# Bias
#    ↓
# Activation Function
#    ↓
# Prediction
#    ↓
# Loss
#    ↓
# Backpropagation
#    ↓
# Weight Update
#    ↓
# Repeat
# ```

# %% [markdown]
# # Activation Functions in Deep Learning
#
# ## What is an Activation Function?
#
# An **Activation Function** is a mathematical function that decides **whether a neuron should be activated or not**. It introduces **non-linearity** into the neural network, enabling it to learn complex patterns.
#
# Without an activation function, a deep neural network behaves like a simple **Linear Regression Model**, regardless of the number of hidden layers.
#
# ---
#
# ## Why Do We Need Activation Functions?
#
# Suppose we have three layers:
#
# ```
# Layer 1
#
# Y = 2X + 5
#
# ↓
#
# Layer 2
#
# Y = 4Y + 2
#
# ↓
#
# Layer 3
#
# Y = 6Y + 1
# ```
#
# After simplifying,
#
# ```
# Y = AX + B
# ```
#
# It is still a **linear equation**.
#
# **Conclusion:** Without an activation function, multiple hidden layers provide no additional learning capability.
#
# ---
#
# ## Working of an Activation Function
#
# ```
# Input Features (X)
#
#         │
#
#         ▼
#
# Multiply with Weights (W)
#
#         │
#
#         ▼
#
# Add Bias (b)
#
#         │
#
#         ▼
#
# Z = WX + b
#
#         │
#
#         ▼
#
# Activation Function
#
#         │
#
#         ▼
#
# Output (A)
# ```
#
# Formula:
#
# ```
# Z = WX + b
#
# A = Activation(Z)
# ```
#
# ---
#
# # Types of Activation Functions
#
# ```
# Activation Functions
#
# │
#
# ├── Linear
#
# ├── Binary Step
#
# ├── Sigmoid
#
# ├── Tanh
#
# ├── ReLU
#
# ├── Leaky ReLU
#
# ├── PReLU
#
# ├── ELU
#
# ├── SELU
#
# ├── Softplus
#
# ├── Softsign
#
# ├── Swish
#
# ├── GELU
#
# ├── Mish
#
# └── Softmax
# ```
#
# ---
#
# # 1. Linear Activation Function
#
# ## Formula
#
# ```
# f(x) = x
# ```
#
# ## Range
#
# ```
# (-∞ , +∞)
# ```
#
# ## Graph
#
# ```
#       /
#
#     /
#
#   /
#
# /
# ```
#
# ## Advantages
#
# - Very simple
# - Used for continuous values
#
# ## Disadvantages
#
# - Cannot learn non-linear patterns
#
# ## Use Case
#
# Regression Output Layer
#
# Example:
#
# - House Price Prediction
# - Temperature Prediction
# - Salary Prediction
#
# Keras
#
# ```python
# Dense(1, activation='linear')
# ```
#
# ---
#
# # 2. Binary Step Function
#
# ## Formula
#
# ```
# If x ≥ 0
#
# Output = 1
#
# Else
#
# Output = 0
# ```
#
# ## Range
#
# ```
# 0 or 1
# ```
#
# ## Graph
#
# ```
# 1 ─────────────
#
# |
#
# |
#
# 0──────────────
# ```
#
# ## Advantages
#
# - Very simple
#
# ## Disadvantages
#
# - Gradient = 0
# - Cannot use Backpropagation
#
# ## Use Case
#
# Historical Perceptron only
#
# Not used in modern Deep Learning.
#
# ---
#
# # 3. Sigmoid Function
#
# ## Formula
#
# ```
# σ(x)=1/(1+e^-x)
# ```
#
# ## Range
#
# ```
# 0 to 1
# ```
#
# ## Graph
#
# ```
# 1 ─────────
#
#         /
#
#       /
#
#     /
#
# 0────────────
# ```
#
# ## Advantages
#
# - Produces probability
# - Smooth curve
#
# ## Disadvantages
#
# - Vanishing Gradient
# - Slow convergence
#
# ## Best Initializer
#
# ```
# Glorot Uniform (Xavier)
# ```
#
# ## Use Case
#
# Binary Classification Output Layer
#
# Examples
#
# - Spam Detection
# - Cancer Prediction
# - Customer Churn
#
# Keras
#
# ```python
# Dense(1, activation='sigmoid')
# ```
#
# ---
#
# # 4. Tanh Function
#
# ## Formula
#
# ```
# tanh(x)
# ```
#
# ## Range
#
# ```
# -1 to +1
# ```
#
# ## Graph
#
# ```
# 1 ───────
#
#      /
#
# ----0------
#
#     \
#
# -1────────
# ```
#
# ## Advantages
#
# - Zero-centered output
# - Better than Sigmoid
#
# ## Disadvantages
#
# - Vanishing Gradient
#
# ## Best Initializer
#
# ```
# Glorot Uniform
# ```
#
# ## Use Case
#
# Older Hidden Layers
#
# RNN (internally)
#
# Keras
#
# ```python
# Dense(64, activation='tanh')
# ```
#
# ---
#
# # 5. ReLU (Rectified Linear Unit)
#
# ## Formula
#
# ```
# f(x)=max(0,x)
# ```
#
# ## Range
#
# ```
# 0 to +∞
# ```
#
# ## Graph
#
# ```
#       /
#
#      /
#
# ____/
# ```
#
# Example
#
# Input
#
# ```
# -8
#
# -2
#
# 0
#
# 4
#
# 7
# ```
#
# Output
#
# ```
# 0
#
# 0
#
# 0
#
# 4
#
# 7
# ```
#
# ## Advantages
#
# - Fast
# - Easy computation
# - No Vanishing Gradient (positive side)
#
# ## Disadvantages
#
# - Dying ReLU Problem
#
# ## Best Initializer
#
# ```
# He Normal
#
# He Uniform
# ```
#
# ## Use Case
#
# Default Hidden Layer Activation
#
# CNN
#
# ANN
#
# Keras
#
# ```python
# Dense(128, activation='relu')
# ```
#
# ---
#
# # 6. Leaky ReLU
#
# ## Formula
#
# ```
# Positive
#
# x
#
# Negative
#
# 0.01x
# ```
#
# Example
#
# Input
#
# ```
# -10
# ```
#
# Output
#
# ```
# -0.1
# ```
#
# ## Advantages
#
# - Solves Dying ReLU
#
# ## Best Initializer
#
# ```
# He Normal
# ```
#
# Keras
#
# ```python
# Dense(64)
#
# LeakyReLU(alpha=0.01)
# ```
#
# ---
#
# # 7. PReLU
#
# ## Formula
#
# ```
# Positive
#
# x
#
# Negative
#
# αx
# ```
#
# Difference
#
# ```
# α is learned automatically.
# ```
#
# ## Advantages
#
# - Better than Leaky ReLU
#
# ## Use Case
#
# Advanced Deep Networks
#
# ---
#
# # 8. ELU
#
# ## Formula
#
# Positive
#
# ```
# x
# ```
#
# Negative
#
# ```
# α(e^x−1)
# ```
#
# ## Advantages
#
# - Smooth
# - Faster convergence
#
# ## Best Initializer
#
# ```
# He Normal
# ```
#
# ---
#
# # 9. SELU
#
# Self-Normalizing Activation
#
# ## Advantages
#
# Automatically maintains
#
# ```
# Mean
#
# Variance
# ```
#
# ## Best Initializer
#
# ```
# Lecun Normal
# ```
#
# ---
#
# # 10. Softplus
#
# ## Formula
#
# ```
# ln(1+e^x)
# ```
#
# Smooth version of ReLU.
#
# ---
#
# # 11. Softsign
#
# ## Formula
#
# ```
# x/(1+|x|)
# ```
#
# Range
#
# ```
# -1 to +1
# ```
#
# Alternative to Tanh.
#
# ---
#
# # 12. Swish
#
# ## Formula
#
# ```
# x × Sigmoid(x)
# ```
#
# Developed by Google.
#
# ## Use Case
#
# EfficientNet
#
# ---
#
# # 13. GELU
#
# ## Formula
#
# ```
# xΦ(x)
# ```
#
# where
#
# ```
# Φ(x)
# ```
#
# is the Gaussian CDF.
#
# ## Advantages
#
# - Better gradient flow
# - Smooth activation
#
# ## Use Case
#
# - GPT
# - BERT
# - Transformers
# - Vision Transformer (ViT)
#
# ---
#
# # 14. Mish
#
# ## Formula
#
# ```
# x × tanh(Softplus(x))
# ```
#
# ## Advantages
#
# - Smooth
# - Better gradient flow
#
# Mostly used in research models.
#
# ---
#
# # 15. Softmax
#
# ## Formula
#
# ```
# e^x / Σe^x
# ```
#
# ## Output
#
# Probability Distribution
#
# Example
#
# ```
# Cat      = 0.70
#
# Dog      = 0.20
#
# Horse    = 0.10
# ```
#
# Total
#
# ```
# 0.70 + 0.20 + 0.10 = 1
# ```
#
# ## Advantages
#
# - Converts outputs into probabilities
# - Sum is always equal to 1
#
# ## Use Case
#
# Multi-Class Classification
#
# Examples
#
# - Digit Recognition
# - Face Recognition
# - Image Classification
#
# Keras
#
# ```python
# Dense(10, activation='softmax')
# ```
#
# ---
#
# # Activation Function Summary
#
# | Activation | Output Range | Best Use |
# |------------|--------------|----------|
# | Linear | (-∞,+∞) | Regression Output |
# | Binary Step | 0,1 | Perceptron (Old) |
# | Sigmoid | 0 to 1 | Binary Classification |
# | Tanh | -1 to 1 | Hidden Layer (Old) |
# | ReLU | 0 to +∞ | Hidden Layers |
# | Leaky ReLU | (-∞,+∞) | Hidden Layers |
# | PReLU | (-∞,+∞) | Advanced Networks |
# | ELU | (-α,+∞) | Hidden Layers |
# | SELU | (-∞,+∞) | Self-Normalizing Networks |
# | Softplus | (0,+∞) | Smooth ReLU |
# | Softsign | -1 to 1 | Alternative to Tanh |
# | Swish | (-∞,+∞) | EfficientNet |
# | GELU | (-∞,+∞) | Transformers / LLMs |
# | Mish | (-∞,+∞) | Research Models |
# | Softmax | 0 to 1 | Multi-Class Output |
#
# ---
#
# # Activation Function Selection
#
# | Problem | Hidden Layer | Output Layer |
# |----------|--------------|--------------|
# | Regression | ReLU | Linear |
# | Binary Classification | ReLU | Sigmoid |
# | Multi-Class Classification | ReLU | Softmax |
# | Multi-Label Classification | ReLU | Sigmoid |
# | CNN | ReLU | Softmax |
# | RNN/LSTM | Tanh + Sigmoid | Depends on Task |
# | Transformers (GPT/BERT) | GELU | Softmax |
#
# ---
#
# # Interview Questions
#
# ### Q1. Why is an activation function required?
#
# To introduce **non-linearity**, allowing the neural network to learn complex relationships.
#
# ---
#
# ### Q2. Which activation function is most commonly used in hidden layers?
#
# **ReLU**
#
# ---
#
# ### Q3. Which activation function is used for Binary Classification?
#
# **Sigmoid**
#
# ---
#
# ### Q4. Which activation function is used for Multi-Class Classification?
#
# **Softmax**
#
# ---
#
#
# ---
#
# # Shortcut for Interviews
#
# ```
# Hidden Layer
# ↓
#
# ReLU
#
# ↓
#
# Binary Output
# ↓
#
# Sigmoid
#
# ↓
#
# Multi-Class Output
# ↓
#
# Softmax
#
# ↓
#
# Regression Output
# ↓
#
# Linear
#
# ↓
#
# LLMs / Transformers
# ↓
#
# GELU
# ```

# %%
import numpy as np
import pandas as pd
import keras
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import keras.models as km
from keras.models import Sequential
from keras import activations, initializers, regularizers, constraints
from keras.layers import Dense, Activation

# %%
dataset=pd.read_csv(r"winequality-red.csv")

# %%
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
dataset["quality"].value_counts()
# Out:
# quality
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: count, dtype: int64

# %%
X = dataset.drop(columns=["quality"])
y = dataset['quality']

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state =123)

# %%
# sc = StandardScaler()
# train_X = sc.fit_transform(train_X)
# test_X = sc.transform(test_X)

# %%
train_X.shape
# Out:
# (1119, 11)

# %%
model = Sequential()
model.add(Dense(units = 11, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
model.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'linear'))
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 11)                  │             132 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │              72 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 4)                   │              28 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 237 (948.00 B)
#  Trainable params: 237 (948.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print(train_X.shape)
print(train_y.shape)
# Out:
# (1119, 11)
# (1119,)

# %%
model.fit(train_X, train_y, epochs=50, batch_size=32, validation_split=0.1)

# Evaluate the model
mse = model.evaluate(test_X, test_y)
print(f'Test Mean Squared Error: {mse}')
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 18ms/step - loss: 32.1887 - val_loss: 33.2521
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 31.4758 - val_loss: 31.9272
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 28.3353 - val_loss: 25.6169
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 17.5066 - val_loss: 10.5905
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 6.6764 - val_loss: 5.7943
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.4774 - val_loss: 5.3496
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.8959 - val_loss: 4.7492
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 4.3463 - val_loss: 4.2131
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.8164 - val_loss: 3.7014
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 3.2777 - val_loss: 3.1646
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.7714 - val_loss: 2.6118
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 2.2580 - val_loss: 2.1922
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7879 - val_loss: 1.7256
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3729 - val_loss: 1.3502
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0571 - val_loss: 1.1127
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8391 - val_loss: 0.9342
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7196 - val_loss: 0.8224
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.6674 - val_loss: 0.8173
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6436 - val_loss: 0.7819
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6344 - val_loss: 0.7733
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6309 - val_loss: 0.7666
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6249 - val_loss: 0.7592
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6162 - val_loss: 0.7382
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6129 - val_loss: 0.7507
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6077 - val_loss: 0.7421
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6023 - val_loss: 0.7114
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.6046 - val_loss: 0.7112
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5971 - val_loss: 0.7230
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5921 - val_loss: 0.7003
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5892 - val_loss: 0.7063
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5849 - val_loss: 0.6981
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5803 - val_loss: 0.6833
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.5779 - val_loss: 0.6906
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.5753 - val_loss: 0.6769
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5706 - val_loss: 0.6714
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5692 - val_loss: 0.6806
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5667 - val_loss: 0.6559
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5622 - val_loss: 0.6679
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5635 - val_loss: 0.6670
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5567 - val_loss: 0.6603
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.5545 - val_loss: 0.6402
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5497 - val_loss: 0.6586
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.5544 - val_loss: 0.6429
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.5511 - val_loss: 0.6297
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.5435 - val_loss: 0.6152
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5443 - val_loss: 0.6140
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5423 - val_loss: 0.6105
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.5376 - val_loss: 0.6221
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5333 - val_loss: 0.6082
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.5317 - val_loss: 0.6157
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4590
# Test Mean Squared Error: 0.4589981138706207

# %%
predictions = model.predict(test_X)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
predictions
# Out:
# array([[6.3544645],
#        [5.1320224],
#        [5.12529  ],
#        [6.0106287],
#        [5.270658 ],
#        [5.539402 ],
#        [5.9263105],
#        [5.4539595],
#        [5.521221 ],
#        [5.733942 ],
#        [5.0101147],
#        [6.652038 ],
#        [5.5219584],
#        [5.646182 ],
#        [5.889139 ],
#        [6.259506 ],
#        [5.070703 ],
#        [5.8337812],
#        [5.767252 ],
#        [5.347698 ],
#        [5.6774106],
#        [5.5219584],
#        [5.6919785],
#        [5.239502 ],
#        [5.320771 ],
#        [5.2490163],
#        [5.9641924],
#        [5.6609435],
#        [5.9421654],
#        [5.6301436],
#        [4.986273 ],
#        [6.1256933],
#        [5.3233557],
#        [5.0631332],
#        [6.040181 ],
#        [4.9353337],
#        [5.5315924],
#        [5.940728 ],
#        [5.3376217],
#        [5.1291895],
#        [5.4610224],
#        [5.8755054],
#        [6.0517216],
#        [5.540181 ],
#        [5.4559383],
#        [5.312339 ],
#        [5.531208 ],
#        [5.048452 ],
#        [5.6563416],
#        [5.6377916],
#        [5.379112 ],
#        [6.233972 ],
#        [5.327275 ],
#        [5.543456 ],
#        [5.036111 ],
#        [6.3805428],
#        [5.0974064],
#        [5.0571675],
#        [5.4482293],
#        [5.174202 ],
#        [5.3720884],
#        [5.7843266],
#        [5.46975  ],
#        [5.5566893],
#        [6.4790373],
#        [5.8364015],
#        [6.109169 ],
#        [5.3517523],
#        [5.2144284],
#        [6.1382313],
#        [5.347757 ],
#        [5.6999617],
#        [5.6561313],
#        [5.9791245],
#        [5.7506914],
#        [5.656147 ],
#        [5.172742 ],
#        [5.1116743],
#        [5.741459 ],
#        [5.6539   ],
#        [5.0000954],
#        [5.057294 ],
#        [6.0050335],
#        [5.1000013],
#        [5.4852896],
#        [5.62568  ],
#        [5.896569 ],
#        [4.9729314],
#        [5.1826   ],
#        [4.8664713],
#        [5.5226603],
#        [5.695106 ],
#        [5.4430146],
#        [6.000667 ],
#        [6.1654778],
#        [5.4779053],
#        [6.0473137],
#        [6.2291117],
#        [5.9698124],
#        [5.4092197],
#        [6.040023 ],
#        [5.9260626],
#        [4.8459272],
#        [5.9449635],
#        [5.382852 ],
#        [5.5274706],
#        [5.654953 ],
#        [6.1842647],
#        [6.237373 ],
#        [5.919037 ],
#        [5.74701  ],
#        [5.7171035],
#        [5.387639 ],
#        [6.055306 ],
#        [5.830048 ],
#        [6.3575335],
#        [5.4777803],
#        [5.0903425],
#        [5.346777 ],
#        [5.1765103],
#        [5.416563 ],
#        [6.2592163],
#        [5.7148447],
#        [5.7886147],
#        [5.435814 ],
#        [5.208233 ],
#        [5.791427 ],
#        [5.6159787],
#        [5.7637396],
#        [5.2827826],
#        [5.4216967],
#        [5.9909773],
#        [5.129716 ],
#        [6.1078715],
#        [5.863063 ],
#        [5.3352394],
#        [5.6273518],
#        [5.169139 ],
#        [6.402871 ],
#        [5.767112 ],
#        [4.994814 ],
#        [5.6773014],
#        [5.5633173],
#        [5.957958 ],
#        [5.3477535],
#        [5.3086677],
#        [5.4945335],
#        [6.074933 ],
#        [5.2367325],
#        [6.3106318],
#        [5.0234194],
#        [5.703883 ],
#        [5.7288656],
#        [6.218496 ],
#        [5.7818065],
#        [5.6545496],
#        [6.1034164],
#        [5.0883865],
#        [5.292479 ],
#        [5.4590397],
#        [5.122195 ],
#        [6.1382313],
#        [6.2270346],
#        [5.419896 ],
#        [5.114999 ],
#        [5.7204094],
#        [5.6013584],
#        [5.3322306],
#        [5.9248075],
#        [5.62372  ],
#        [5.393379 ],
#        [5.419796 ],
#        [5.6412497],
#        [5.7682085],
#        [5.51472  ],
#        [5.888837 ],
#        [5.4575515],
#        [5.4430146],
#        [5.6190023],
#        [5.1987753],
#        [5.6567097],
#        [5.3459034],
#        [6.0691676],
#        [5.8700695],
#        [6.3984632],
#        [6.224741 ],
#        [5.935462 ],
#        [5.6079483],
#        [5.3041787],
#        [5.3766756],
#        [6.8308144],
#        [6.018755 ],
#        [5.695445 ],
#        [5.4475193],
#        [5.40731  ],
#        [6.1884336],
#        [5.4575515],
#        [5.8612423],
#        [5.3614016],
#        [5.256643 ],
#        [5.890479 ],
#        [5.776657 ],
#        [5.817411 ],
#        [6.0983887],
#        [5.4390936],
#        [6.034964 ],
#        [5.576786 ],
#        [6.0152073],
#        [5.7246346],
#        [4.9950457],
#        [5.9405766],
#        [5.5491123],
#        [6.079573 ],
#        [5.5342007],
#        [5.3797903],
#        [5.7351694],
#        [5.7139053],
#        [5.9340343],
#        [5.666216 ],
#        [5.6285467],
#        [6.0033264],
#        [5.0971813],
#        [5.5102363],
#        [6.243914 ],
#        [5.699923 ],
#        [5.476326 ],
#        [6.259506 ],
#        [6.1101246],
#        [5.1373377],
#        [5.461616 ],
#        [5.123685 ],
#        [5.4538345],
#        [5.735688 ],
#        [5.566187 ],
#        [5.727194 ],
#        [5.766218 ],
#        [5.1960564],
#        [5.4761763],
#        [6.010137 ],
#        [5.4988465],
#        [5.225089 ],
#        [5.360259 ],
#        [5.6938224],
#        [5.436652 ],
#        [5.1762075],
#        [5.7096004],
#        [5.390028 ],
#        [6.205427 ],
#        [5.649029 ],
#        [6.1423264],
#        [5.608332 ],
#        [5.347757 ],
#        [5.2707644],
#        [5.7477636],
#        [5.653572 ],
#        [5.909358 ],
#        [5.2210236],
#        [5.7031565],
#        [5.2379723],
#        [5.045086 ],
#        [5.249216 ],
#        [5.0241857],
#        [5.637105 ],
#        [5.3571324],
#        [5.9922814],
#        [6.8913145],
#        [5.444961 ],
#        [5.695406 ],
#        [5.3074446],
#        [5.3072996],
#        [6.1509895],
#        [6.4266224],
#        [5.6761684],
#        [5.68635  ],
#        [5.885809 ],
#        [5.3108587],
#        [5.2325134],
#        [5.19835  ],
#        [5.2682443],
#        [5.431402 ],
#        [6.1509895],
#        [6.0124393],
#        [5.2998514],
#        [5.292535 ],
#        [5.130451 ],
#        [4.931299 ],
#        [6.3984623],
#        [5.9119244],
#        [5.66575  ],
#        [5.691416 ],
#        [5.955186 ],
#        [5.4304686],
#        [5.642451 ],
#        [6.0187554],
#        [5.266677 ],
#        [5.8774433],
#        [6.2722034],
#        [5.7476883],
#        [5.7574744],
#        [5.4482145],
#        [5.095337 ],
#        [5.8308287],
#        [5.2821374],
#        [5.924863 ],
#        [5.2241383],
#        [5.230198 ],
#        [5.6285467],
#        [5.4501944],
#        [5.9077272],
#        [5.799797 ],
#        [5.1149597],
#        [5.586173 ],
#        [5.5620685],
#        [6.3271523],
#        [5.4685526],
#        [5.50385  ],
#        [5.724781 ],
#        [5.6136093],
#        [5.1430106],
#        [5.246113 ],
#        [6.096966 ],
#        [5.366988 ],
#        [5.7732744],
#        [5.249216 ],
#        [5.1275077],
#        [5.689726 ],
#        [6.202932 ],
#        [5.971224 ],
#        [5.0702457],
#        [5.317643 ],
#        [6.2513103],
#        [5.6418505],
#        [5.257339 ],
#        [4.8408966],
#        [5.1430106],
#        [5.546565 ],
#        [5.119195 ],
#        [6.1898956],
#        [5.7074804],
#        [5.303366 ],
#        [5.737877 ],
#        [5.2732263],
#        [5.984149 ],
#        [5.298176 ],
#        [5.8584137],
#        [5.591762 ],
#        [5.292479 ],
#        [5.8946447],
#        [5.1335487],
#        [6.0420775],
#        [5.6687956],
#        [5.3720884],
#        [5.326988 ],
#        [5.8866673],
#        [5.1624365],
#        [5.374735 ],
#        [5.5211725],
#        [5.5944433],
#        [5.0671244],
#        [5.1598454],
#        [5.401429 ],
#        [6.145281 ],
#        [5.0789123],
#        [6.005591 ],
#        [5.606743 ],
#        [5.584944 ],
#        [5.905173 ],
#        [5.5731077],
#        [5.7091665],
#        [5.4181423],
#        [5.6555853],
#        [5.3851805],
#        [6.1366773],
#        [5.2776756],
#        [6.133029 ],
#        [6.3493176],
#        [5.382852 ],
#        [5.871103 ],
#        [5.3714957],
#        [6.337598 ],
#        [5.4119477],
#        [5.597595 ],
#        [5.8469973],
#        [6.0073304],
#        [5.5937195],
#        [6.4154296],
#        [5.7318053],
#        [5.14342  ],
#        [5.156504 ],
#        [5.2415905],
#        [5.4270687],
#        [5.55295  ],
#        [5.0044613],
#        [6.0992584],
#        [5.535587 ],
#        [5.7847037],
#        [5.4120145],
#        [6.120014 ],
#        [5.622693 ],
#        [5.6531734],
#        [6.570915 ],
#        [5.30425  ],
#        [5.3795395],
#        [5.387766 ],
#        [5.5566893],
#        [5.1831474],
#        [5.1015286],
#        [5.2826343],
#        [5.0044127],
#        [5.7116375],
#        [5.281609 ],
#        [5.5702095],
#        [5.094011 ],
#        [5.3766756],
#        [5.4529915],
#        [6.20796  ],
#        [5.7299356],
#        [5.2639227],
#        [5.4932456],
#        [5.5595255],
#        [5.689726 ],
#        [5.5393906],
#        [5.8882914],
#        [5.53895  ],
#        [5.361256 ],
#        [5.544738 ],
#        [5.09728  ],
#        [5.6938224],
#        [5.8308287],
#        [5.8239193],
#        [5.6333647],
#        [5.9752264],
#        [5.78765  ],
#        [5.2825813],
#        [5.2556067],
#        [5.4308443],
#        [5.649639 ],
#        [5.3762026],
#        [5.443084 ],
#        [5.3376217],
#        [5.742734 ],
#        [5.4266634],
#        [6.341997 ],
#        [5.5059757],
#        [5.2162676],
#        [6.4039917],
#        [5.080122 ],
#        [5.222119 ],
#        [5.3798227],
#        [5.6124153],
#        [5.855424 ],
#        [5.2632794],
#        [5.0798655],
#        [5.0233955],
#        [5.800948 ],
#        [6.197626 ],
#        [5.197957 ],
#        [5.9477434],
#        [5.3649793],
#        [5.2545476],
#        [6.5197086],
#        [6.03892  ],
#        [6.2752542],
#        [5.673404 ],
#        [5.590259 ],
#        [6.1352882],
#        [5.3529744],
#        [5.425336 ],
#        [5.303366 ],
#        [6.3608465],
#        [5.6495075],
#        [6.205427 ],
#        [6.558712 ],
#        [5.245911 ],
#        [5.2858677],
#        [5.4254065],
#        [5.960964 ],
#        [5.2124405],
#        [6.022006 ],
#        [5.361    ]], dtype=float32)
